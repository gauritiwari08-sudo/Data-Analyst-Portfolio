# %% [markdown]
# <a href="https://colab.research.google.com/github/gauritiwari08-sudo/Data-Analyst-Portfolio/blob/main/Python/prog1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this is sinle line comment
'''
this is multi line comment
this is multi line comment
'''
print("Hello World 222")
name=input("Enter your name: ")
print("Hello " + name)
print("Hello " + name + " Welcome to Python Programming")
print(f"hello {name} Welcome to Python Programming  ")
print(f"hello {name} Welcome to Python Programming  ")
# Out:
# Hello World 222
# Enter your name: gauri
# Hello gauri
# Hello gauri Welcome to Python Programming
# hello gauri Welcome to Python Programming
# hello gauri Welcome to Python Programming

# %%
complex_no=2+3j
print(complex_no)
print(type(complex_no))
print(complex_no.real)
print(complex_no.imag)
print(complex_no.conjugate())
# Out:
# (2+3j)
# <class 'complex'>
# 2.0
# 3.0
# (2-3j)

# %%
# Taking user inputs of different data types
name = input("Enter your name: ")  # String input
age = int(input("Enter your age: "))  # Integer input
height = float(input("Enter your height in meters: "))  # Float input
active = input("Are you active? (yes/no): ").lower() == "yes"  # Boolean input
# Displaying the stored information
print("\nUser Information:")
print(f"Name: {name} (Type: {type(name)})")
print(f"Age: {age} (Type: {type(age)})")
print(f"Height: {height} meters (Type: {type(height)})")
print(f"Active Status: {active} (Type: {type(active)})")
# Out:
# Enter your name: gauri
# Enter your age: 32
# Enter your height in meters: 5.4
# Are you active? (yes/no): yes
#
# User Information:
# Name: gauri (Type: <class 'str'>)
# Age: 32 (Type: <class 'int'>)
# Height: 5.4 meters (Type: <class 'float'>)
# Active Status: True (Type: <class 'bool'>)

# %%
#arithmetic operator
print("2/3=",2/3)
print("2//3=",2//3)
print("2**3=",2**3)
# Out:
# 2/3= 0.6666666666666666
# 2//3= 0
# 2**3= 8

# %%
#comparison operator
# Taking two numbers as input from the user
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
# Applying comparison operators and displaying results
print(f"{a} > {b}  :", a > b)
print(f"{a} < {b}  :", a < b)
print(f"{a} >= {b} :", a >= b)
print(f"{a} <= {b} :", a <= b)
print(f"{a} == {b} :", a == b)
print(f"{a} != {b} :", a != b)
# Out:
# Enter first number: 4
# Enter second number: 5
# 4 > 5  : False
# 4 < 5  : True
# 4 >= 5 : False
# 4 <= 5 : True
# 4 == 5 : False
# 4 != 5 : True

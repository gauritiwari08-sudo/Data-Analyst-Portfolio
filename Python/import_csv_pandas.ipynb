# %% [markdown]
# <a href="https://colab.research.google.com/github/gauritiwari08-sudo/Data-Analyst-Portfolio/blob/main/Python/import_csv_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing csv file for pandas operation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive/My Drive

# %%
cd My Drive
# Out:
# [Errno 2] No such file or directory: 'My Drive'
# /content/drive/My Drive

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
print(df) # print first and last five rows

print(df.to_string()) # print all rows
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# ...

# %%
# selection by coloumn
print(df["Name"])
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 145       Moltres
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# Name: Name, Length: 150, dtype: object

# %%
#selecting multiple coloumn
print(df[["Name","Height","Weight"]])
# Out:
#            Name  Height  Weight
# 0     Bulbasaur     0.7     6.9
# 1       Ivysaur     1.0    13.0
# 2      Venusaur     2.0   100.0
# 3    Charmander     0.6     8.5
# 4    Charmeleon     1.1    19.0
# ..          ...     ...     ...
# 145     Moltres     2.0    60.0
# 146     Dratini     1.8     3.3
# 147   Dragonair     4.0    16.5
# 148   Dragonite     2.2   210.0
# 149      Mewtwo     2.0   122.0
#
# [150 rows x 3 columns]

# %%
#SElection by row using interger location
#print(df.iloc[5]) #displays only 5 th row

#print(df.iloc[1:7]) #displays rows from 1 st to 7 th

#print(df.iloc[0:11:2]) #displays from 0 to 11 every 2nd row

print(df.iloc[0:11:2,0:3]) #displays from 0 to 11 every 2nd row with only first 3 cols
# Out:
#     No        Name  Type1
# 0    1   Bulbasaur  Grass
# 2    3    Venusaur  Grass
# 4    5  Charmeleon   Fire
# 6    7    Squirtle  Water
# 8    9   Blastoise  Water
# 10  11     Metapod    Bug

# %%
# selection by label for that we must change label to name
df= pd.read_csv("sample.csv",index_col="Name")
#print (df)

#print(df.loc["Mewtwo"]) # displays all cols for this row

#print(df.loc["Mewtwo", ["Height","Weight"]]) #displays only height and weight cols

# %%
pokemon = input("Enter a pokeman name:")

try:
  print(df.loc[pokemon])
except KeyError:
  print(f"{pokemon} not found")
# Out:
# Enter a pokeman name:dsff
# dsff not found

# %%
# Filtering : Keeping the rows that match a condition

tall_pokemon = df[df["Height"]>=2]
#print(tall_pokemon)

heavy_pokemon = df[df["Weight"]>=200]
#print(heavy_pokemon)

water_pokemon = df[(df["Type1"]=="Water") | (df["Type2"]=="Water")  ]
#print(water_pokemon)

fire_Flying = df[(df["Type1"]=="Fire") & (df["Type2"]=="Flying")  ]
print(fire_Flying)
# Out:
#             No Type1   Type2  Height  Weight  Legendary
# Name
# Charizard    6  Fire  Flying     1.7    90.5          0
# Moltres    146  Fire  Flying     2.0    60.0          1

# %%
# Aggreagation : Reduces a set of values intp a single value
#                it often used it with groupby()

# Whole Dataframe
# print(df.mean(numeric_only=True))

# print(df.sum(numeric_only=True))

# print(df.min(numeric_only=True))

# print(df.max(numeric_only=True))

# print(df.count())

# Single coloumn

# print(df["Height"].mean())

# print(df["Height"].sum())

# print(df["Height"].min())

# print(df["Height"].max())

# print(df["Height"].count())

#group by
group = df.groupby("Type1")
print(group["Height"].mean())
print(group["Height"].sum())
print(group["Height"].min())
print(group["Height"].max())
print(group["Height"].count())
# Out:
# Type1
# Bug         0.900000
# Dragon      2.666667
# Electric    0.855556
# Fairy       0.950000
# Fighting    1.185714
# Fire        1.216667
# Ghost       1.466667
# Grass       1.083333
# Ground      0.850000
# Ice         1.550000
# Normal      0.986364
# Poison      1.221429
# Psychic     1.371429
# Rock        1.844444
# Water       1.300000
# Name: Height, dtype: float64
# Type1
# Bug         10.8
# Dragon       8.0
# Electric     7.7
# Fairy        1.9
# Fighting     8.3
# Fire        14.6
# Ghost        4.4
# Grass       13.0
# Ground       6.8
# Ice          3.1
# Normal      21.7
# Poison      17.1
# Psychic      9.6
# Rock        16.6
# Water       36.4
# Name: Height, dtype: float64
# Type1
# Bug         0.3
# Dragon      1.8
# Electric    0.3
# Fairy       0.6
# Fighting    0.5
# Fire        0.6
# Ghost       1.3
# Grass       0.4
# Ground      0.2
# Ice         1.4
# Normal      0.3
# Poison      0.4
# Psychic     0.9
# Rock        0.4
# Water       0.3
# ...

# %% [markdown]
# **Data Cleaning **: the process of fixing or removing incomplete incorrect or irrelevant data.
# 75% of work done with pandas is data cleaning

# %%
# 1. Drop irrelevent Coloumn
df=df.drop(columns=["Legendary","No"])
print(df)
# Out:
#            Name    Type1   Type2  Height  Weight
# 0     Bulbasaur    Grass  Poison     0.7     6.9
# 1       Ivysaur    Grass  Poison     1.0    13.0
# 2      Venusaur    Grass  Poison     2.0   100.0
# 3    Charmander     Fire     NaN     0.6     8.5
# 4    Charmeleon     Fire     NaN     1.1    19.0
# ..          ...      ...     ...     ...     ...
# 145     Moltres     Fire  Flying     2.0    60.0
# 146     Dratini   Dragon     NaN     1.8     3.3
# 147   Dragonair   Dragon     NaN     4.0    16.5
# 148   Dragonite   Dragon  Flying     2.2   210.0
# 149      Mewtwo  Psychic     NaN     2.0   122.0
#
# [150 rows x 5 columns]

# %%
# 2. Handel Missing Data
# dropna = drop not available

df=pd.read_csv("sample.csv")

# df=df.dropna(subset=["Type2"])
# print(df.to_string())

df=df.fillna({"Type2": "None"})
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire      None     0.6     8.5          0
# 4      5  Charmeleon      Fire      None     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water      None     0.5     9.0          0
# 7      8   Wartortle     Water      None     1.0    22.5          0
# 8      9   Blastoise     Water      None     1.6    85.5          0
# 9     10    Caterpie       Bug      None     0.3     2.9          0
# 10    11     Metapod       Bug      None     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %%
# 3. Fix inconsistent values

df["Type1"]=df["Type1"].replace({"Grass":"GRASS"})
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     GRASS    Poison     0.7     6.9          0
# 1      2     Ivysaur     GRASS    Poison     1.0    13.0          0
# 2      3    Venusaur     GRASS    Poison     2.0   100.0          0
# 3      4  Charmander      Fire      None     0.6     8.5          0
# 4      5  Charmeleon      Fire      None     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water      None     0.5     9.0          0
# 7      8   Wartortle     Water      None     1.0    22.5          0
# 8      9   Blastoise     Water      None     1.6    85.5          0
# 9     10    Caterpie       Bug      None     0.3     2.9          0
# 10    11     Metapod       Bug      None     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %%
# 4. Standarardize text

df["Name"] = df["Name"].str.lower()

print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   bulbasaur    GRASS  Poison     0.7     6.9          0
# 1      2     ivysaur    GRASS  Poison     1.0    13.0          0
# 2      3    venusaur    GRASS  Poison     2.0   100.0          0
# 3      4  charmander     Fire    None     0.6     8.5          0
# 4      5  charmeleon     Fire    None     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     moltres     Fire  Flying     2.0    60.0          1
# 146  147     dratini   Dragon    None     1.8     3.3          0
# 147  148   dragonair   Dragon    None     4.0    16.5          0
# 148  149   dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      mewtwo  Psychic    None     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
# 5. Fix data types
df["Legendary"]=df["Legendary"].astype(bool)
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   bulbasaur     GRASS    Poison     0.7     6.9      False
# 1      2     ivysaur     GRASS    Poison     1.0    13.0      False
# 2      3    venusaur     GRASS    Poison     2.0   100.0      False
# 3      4  charmander      Fire      None     0.6     8.5      False
# 4      5  charmeleon      Fire      None     1.1    19.0      False
# 5      6   charizard      Fire    Flying     1.7    90.5      False
# 6      7    squirtle     Water      None     0.5     9.0      False
# 7      8   wartortle     Water      None     1.0    22.5      False
# 8      9   blastoise     Water      None     1.6    85.5      False
# 9     10    caterpie       Bug      None     0.3     2.9      False
# 10    11     metapod       Bug      None     0.7     9.9      False
# 11    12  butterfree       Bug    Flying     1.1    32.0      False
# 12    13      weedle       Bug    Poison     0.3     3.2      False
# ...

# %%
# 6. Remove Duplicates

df=df.drop_duplicates()
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]
